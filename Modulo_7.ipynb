# %%
class Nodo():
    def __init__ (self, valor,padre = None):
        self.valor = valor
        self.padre = padre
        self.izquierda = None
        self.derecha = None
        self.h = 0
    def __str__(self):
        return str(self.valor)

class ArbolBinario():

    def __init__(self,raiz=None):
        self.len = 0
        self.h = 0
        self._listaRetorno = str()
        self._hojas = 0
        self._hijos = 0
        self._racimo = 0
        if raiz == None:
            self.raiz = None
        elif type(raiz) == int:
            self.raiz = None
        else:
            self.raiz = None
            self.insertar(raiz)


    def _insertarAux(self, valor):
        Nuevo = Nodo(valor)
        self.len+=1

        if self.len == 1:
            self.raiz = Nuevo
            self.h = 1
            Nuevo.h = 1
            return False

        padre = self.raiz
        aux = 2
        while True:

            if Nuevo.valor < padre.valor and padre.izquierda == None:
                Nuevo.padre = padre
                padre.izquierda = Nuevo
                Nuevo.h = aux
                if aux>self.h:
                    self.h = aux
                return True

            elif Nuevo.valor < padre.valor:
                padre = padre.izquierda

            elif Nuevo.valor > padre.valor and padre.derecha == None:
                Nuevo.padre = padre
                padre.derecha = Nuevo
                if aux>self.h:
                    self.h = aux
                Nuevo.h = aux
                return True

            elif Nuevo.valor > padre.valor:
                padre = padre.derecha

            else:
                self.size -= 1
                return False
            aux += 1


    def insertar(self, valores):
        for valor in valores:
            self._insertarAux(valor)


    def busque(self, valor):
        nodo = self.raiz
        while nodo.valor != valor:
            if valor < nodo.valor and nodo.izquierda != None:
                nodo = nodo.izquierda
            elif valor > nodo.valor and nodo.derecha != None:
                nodo = nodo.derecha
            else:
                return False
        return nodo


    def PreOrden(self,raiz):
        if self.len == 0:
            return

        self._listaRetorno+=str(raiz.valor)
        if raiz.izquierda != None:
            self.PreOrden(raiz.izquierda)

        if raiz.derecha != None:
            self.PreOrden(raiz.derecha)


        return self._listaRetorno

for i in range(int(input())):
  conjunto = (list(map(int, input().split())))
  conjunto.pop()
  arbol = ArbolBinario()
  arbol.insertar(conjunto)
  print(arbol.PreOrden(arbol.raiz))
# Out:
# 3
# 2 3 1 -1
# 213
# 9 8 7 6 5 -1
# 98765
# 50 70 30 60 40 -1
# 5030407060

# %%
class Nodo():
    def __init__ (self, valor,padre = None):
        self.valor = valor
        self.padre = padre
        self.izquierda = None
        self.derecha = None
        self.h = 0
    def __str__(self):
        return str(self.valor)

class ArbolBinario():

    def __init__(self,raiz=None):
        self.len = 0
        self.h = 0
        self._listaRetorno = str()
        self._hojas = 0
        self._hijos = 0
        self._racimo = 0
        if raiz == None:
            self.raiz = None
        elif type(raiz) == int:
            self.raiz = None
        else:
            self.raiz = None
            self.insertar(raiz)


    def _insertarAux(self, valor):
        Nuevo = Nodo(valor)
        self.len+=1

        if self.len == 1:
            self.raiz = Nuevo
            self.h = 1
            Nuevo.h = 1
            return False

        padre = self.raiz
        aux = 2
        while True:

            if Nuevo.valor < padre.valor and padre.izquierda == None:
                Nuevo.padre = padre
                padre.izquierda = Nuevo
                Nuevo.h = aux
                if aux>self.h:
                    self.h = aux
                return True

            elif Nuevo.valor < padre.valor:
                padre = padre.izquierda

            elif Nuevo.valor > padre.valor and padre.derecha == None:
                Nuevo.padre = padre
                padre.derecha = Nuevo
                if aux>self.h:
                    self.h = aux
                Nuevo.h = aux
                return True

            elif Nuevo.valor > padre.valor:
                padre = padre.derecha

            else:
                self.size -= 1
                return False
            aux += 1


    def insertar(self, valores):
        for valor in valores:
            self._insertarAux(valor)


    def busque(self, valor):
        nodo = self.raiz
        while nodo.valor != valor:
            if valor < nodo.valor and nodo.izquierda != None:
                nodo = nodo.izquierda
            elif valor > nodo.valor and nodo.derecha != None:
                nodo = nodo.derecha
            else:
                return False
        return nodo

for i in range(int(input())):
  conjunto = (list(map(int, input().split())))
  conjunto.pop()
  arbol = ArbolBinario()
  arbol.insertar(conjunto)
  print(arbol.h)
# Out:
# 3
# 2 3 1 -1
# 2
# 9 8 7 6 5 -1
# 5
# 50 70 30 60 40 -1
# 3

# %%
class Nodo():
    def __init__ (self, valor,padre = None):
        self.valor = valor
        self.padre = padre
        self.izquierda = None
        self.derecha = None
        self.h = 0
    def __str__(self):
        return str(self.valor)

class ArbolBinario():

    def __init__(self,raiz=None):
        self.len = 0
        self.h = 0
        self._listaRetorno = str()
        self._hojas = 0
        self._hijos = 0
        self._racimo = 0
        if raiz == None:
            self.raiz = None
        elif type(raiz) == int:
            self.raiz = None
        else:
            self.raiz = None
            self.insertar(raiz)


    def _insertarAux(self, valor):
        Nuevo = Nodo(valor)
        self.len+=1

        if self.len == 1:
            self.raiz = Nuevo
            self.h = 1
            Nuevo.h = 1
            return False

        padre = self.raiz
        aux = 2
        while True:

            if Nuevo.valor < padre.valor and padre.izquierda == None:
                Nuevo.padre = padre
                padre.izquierda = Nuevo
                Nuevo.h = aux
                if aux>self.h:
                    self.h = aux
                return True

            elif Nuevo.valor < padre.valor:
                padre = padre.izquierda

            elif Nuevo.valor > padre.valor and padre.derecha == None:
                Nuevo.padre = padre
                padre.derecha = Nuevo
                if aux>self.h:
                    self.h = aux
                Nuevo.h = aux
                return True

            elif Nuevo.valor > padre.valor:
                padre = padre.derecha

            else:
                self.size -= 1
                return False
            aux += 1


    def insertar(self, valores):
        for valor in valores:
            self._insertarAux(valor)


    def busque(self, valor):
        nodo = self.raiz
        while nodo.valor != valor:
            if valor < nodo.valor and nodo.izquierda != None:
                nodo = nodo.izquierda
            elif valor > nodo.valor and nodo.derecha != None:
                nodo = nodo.derecha
            else:
                return False
        return nodo

    def contarhojas(self,raiz):
        if self.len == 0:
            return

        if raiz.derecha ==None and raiz.izquierda == None:
            self._hojas += 1

        if raiz.izquierda != None:
            self.contarhojas(raiz.izquierda)

        if raiz.derecha != None:
            self.contarhojas(raiz.derecha)
        return self._hojas

for i in range(int(input())):
  conjunto = (list(map(int, input().split())))
  conjunto.pop()
  arbol = ArbolBinario()
  arbol.insertar(conjunto)
  print(arbol.contarhojas(arbol.raiz))
# Out:
# 3
# 2 3 1 -1
# 2
# 9 8 7 6 5 -1
# 1
# 50 70 30 60 40 -1
# 2

# %%
class Nodo():
    def __init__ (self, valor,padre = None):
        self.valor = valor
        self.padre = padre
        self.izquierda = None
        self.derecha = None
        self.h = 0
    def __str__(self):
        return str(self.valor)

class ArbolBinario():

    def __init__(self,raiz=None):
        self.len = 0
        self.h = 0
        self._listaRetorno = []
        self._hojas = 0
        self._hijos = 0
        self._racimo = 0
        if raiz == None:
            self.raiz = None
        elif type(raiz) == int:
            self.raiz = None
        else:
            self.raiz = None
            self.insertar(raiz)


    def _insertarAux(self, valor):
        Nuevo = Nodo(valor)
        self.len+=1

        if self.len == 1:
            self.raiz = Nuevo
            self.h = 1
            Nuevo.h = 1
            return False

        padre = self.raiz
        aux = 2
        while True:

            if Nuevo.valor < padre.valor and padre.izquierda == None:
                Nuevo.padre = padre
                padre.izquierda = Nuevo
                Nuevo.h = aux
                if aux>self.h:
                    self.h = aux
                return True

            elif Nuevo.valor < padre.valor:
                padre = padre.izquierda

            elif Nuevo.valor > padre.valor and padre.derecha == None:
                Nuevo.padre = padre
                padre.derecha = Nuevo
                if aux>self.h:
                    self.h = aux
                Nuevo.h = aux
                return True

            elif Nuevo.valor > padre.valor:
                padre = padre.derecha

            else:
                self.size -= 1
                return False
            aux += 1


    def insertar(self, valores):
        for valor in valores:
            self._insertarAux(valor)

    def busque(self, valor):
        nodo = self.raiz
        while nodo.valor != valor:
            if valor < nodo.valor and nodo.izquierda != None:
                nodo = nodo.izquierda
            elif valor > nodo.valor and nodo.derecha != None:
                nodo = nodo.derecha
            else:
                return False
        return nodo

    def contarHijos(self,raiz):
        if self.len == 0:
            return

        if (raiz.derecha == None) ^ (raiz.izquierda == None):
            self._hijos += 1

        if raiz.izquierda != None:
            self.contarHijos(raiz.izquierda)

        if raiz.derecha != None:
            self.contarHijos(raiz.derecha)
        return self._hijos

for i in range(int(input())):
  conjunto = (list(map(int, input().split())))
  conjunto.pop()
  arbol = ArbolBinario()
  arbol.insertar(conjunto)
  print(arbol.contarHijos(arbol.raiz))
# Out:
# 3
# 2 3 1 -1
# 0
# 9 8 7 6 5 -1
# 4
# 50 70 30 60 40 -1
# 2

# %%
class Nodo:
    def __init__(self, valor):
        self.valor = valor
        self.izquierda = None
        self.derecha = None


def insertar_nodo(raiz, valor):
    if raiz is None:
        return Nodo(valor)
    if valor < raiz.valor:
        raiz.izquierda = insertar_nodo(raiz.izquierda, valor)
    else:
        raiz.derecha = insertar_nodo(raiz.derecha, valor)
    return raiz


def imprimir_arbol(raiz, nivel=0):
    if raiz is not None:
        imprimir_arbol(raiz.derecha, nivel + 1)
        print('\t' * nivel + str(raiz.valor))
        imprimir_arbol(raiz.izquierda, nivel + 1)

for i in range(int(input())):
  conjunto = (list(map(int, input().split())))
  conjunto.pop()
  raiz = None
  for elemento in conjunto:
     raiz = insertar_nodo(raiz, elemento)
  imprimir_arbol(raiz)
  print("")
# Out:
# 3
# 2 3 1 -1
# 	3
# 2
# 	1
#
# 4 3 2 1 -1
# 4
# 	3
# 		2
# 			1
#
# 50 20 70 60 30 10 80 -1
# 		80
# 	70
# 		60
# 50
# 		30
# 	20
# 		10

# %%
class Nodo():
    def __init__ (self, valor,padre = None):
        self.valor = valor
        self.padre = padre
        self.izquierda = None
        self.derecha = None
        self.h = 0
    def __str__(self):
        return str(self.valor)

class ArbolBinario():

    def __init__(self,raiz=None):
        self.len = 0
        self.h = 0
        self._listaRetorno = []
        self._hojas = 0
        self._hijos = 0
        self._racimo = 0
        if raiz == None:
            self.raiz = None
        elif type(raiz) == int:
            self.raiz = None
        else:
            self.raiz = None
            self.insertar(raiz)


    def _insertarAux(self, valor):
        Nuevo = Nodo(valor)
        self.len+=1

        if self.len == 1:
            self.raiz = Nuevo
            self.h = 1
            Nuevo.h = 1
            return False

        padre = self.raiz
        aux = 2
        while True:

            if Nuevo.valor < padre.valor and padre.izquierda == None:
                Nuevo.padre = padre
                padre.izquierda = Nuevo
                Nuevo.h = aux
                if aux>self.h:
                    self.h = aux
                return True

            elif Nuevo.valor < padre.valor:
                padre = padre.izquierda

            elif Nuevo.valor > padre.valor and padre.derecha == None:
                Nuevo.padre = padre
                padre.derecha = Nuevo
                if aux>self.h:
                    self.h = aux
                Nuevo.h = aux
                return True

            elif Nuevo.valor > padre.valor:
                padre = padre.derecha

            else:
                self.size -= 1
                return False
            aux += 1


    def insertar(self, valores):
        for valor in valores:
            self._insertarAux(valor)


    def busque(self, valor):
        nodo = self.raiz
        while nodo.valor != valor:
            if valor < nodo.valor and nodo.izquierda != None:
                nodo = nodo.izquierda
            elif valor > nodo.valor and nodo.derecha != None:
                nodo = nodo.derecha
            else:
                return False
        return nodo

    def VerificarRacimo(self,raiz):
        if self.len == 0:
            return

        if self.h == raiz.h:
            self._racimo += 1
        if raiz.izquierda != None:
            self.VerificarRacimo(raiz.izquierda)

        if raiz.derecha != None:
            self.VerificarRacimo(raiz.derecha)
        return 2**(self.h-1) == self._racimo

for i in range(int(input())):
  conjunto = (list(map(int, input().split())))
  conjunto.pop()
  arbol = ArbolBinario()
  arbol.insertar(conjunto)
  if arbol.VerificarRacimo(arbol.raiz) == True:
    print("racimo de uva")
  else:
    print("no es")
# Out:
# 3
# 2 3 1 -1
# racimo de uva
# 1 2 3 -1
# no es
# 50 20 70 60 30 10 80 -1
# racimo de uva
