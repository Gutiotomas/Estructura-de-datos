# %%
N = int(input())
print(N*N)
# Out:
# 7
# 49

# %%
N=int(input())
for i in range (N):
  if i%2==0:
   print("Hola mundo")
  else:
   print("Hello world")
# Out:
# 7
# Hola mundo
# Hello world
# Hola mundo
# Hello world
# Hola mundo
# Hello world
# Hola mundo

# %%
Q=0
R=0
for i in range(int(input())):
  N=int(input())
  if N>=0:
    Q+=N
  else:
    R+=N
print("positivos ", Q, ", negativos ", R, sep="")
# Out:
# 2
# 4
# -2
# positivos 4, negativos -2

# %%
N=int(input())
if N%2==0:
  print("es multiplo de 2")
elif N%3==0:
  print("es multiplo de 3")
elif N%5==0:
  print("es multiplo de 5")
elif N%7==0:
  print("es multiplo de 7")
else:
  print("no es multiplo de ninguno de los primeros cuatro primos")
# Out:
# 64
# es multiplo de 2

# %%
A=int(input())
B=int(input())
potencia=1
while A**potencia <= B:
  print(A**potencia)
  potencia +=1
# Out:
# 4
# 200
# 4
# 16
# 64

# %%
N=int(input())
print(N)
for i in range(1000000):
  if N==1:
    break
  if N%2==0:
      N=N//2
      print(N)
  else:
      N=3*N+1
      print(N)
# Out:
# 11
# 11
# 34
# 17
# 52
# 26
# 13
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1
